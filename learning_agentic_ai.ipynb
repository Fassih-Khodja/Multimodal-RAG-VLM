# %% [markdown]
# ## Understanding reAct

# %% [markdown]
# so react is just a prompting system  , or just desing the prompting system to let the ai do the reasoning and the acting based on chain of thought ,, so basically it is just telling the llm model (which is the agentic ai) to that after getting a prompt , ypu should plan what do (which is the reasoning ) , then based on that you should act (by calling atool ) and then based on the result  reason again to make another decision (like calling other tool , redoing the same tool ) , and this is a loop that end when te model knows that he ends (so final answer ) the one that sends to the user ,
# HOw this is done by the developper ?? , just wrap the prompt inside this system , so make the prompt explicitly tell : take this prompt , and first do the reasoning , then act then wait then loop until final respnse ,, and this is exactly what happen inside one of the frameworks like the langraoh , so we don't have to write it , but it is dona by default
# Remarc : the model doesn't know how to wait , so he stop after giving the tool that shold be executed , and the code after executed the tool , should restarted the model with this result of the tool as observation

# %% [markdown]
# ## Understanding memory management
